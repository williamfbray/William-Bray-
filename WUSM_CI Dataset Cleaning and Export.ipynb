# %%
import pandas as pd
import numpy as np
import os
import datetime

# Jupyter notebook - widen cells
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
## Select Columsn For Analysis

def select_cols(df):   
    cols = [

#         LastName,
#         FirstName,
        'MRN',
#         DOB,
        'Exclude',
        'Comments_ReasonsForExclusion',
        'Source',
        'Lat',
        'SequentialCI',
        'Surgeon',
        'YOS',
        'DOS',
        'DOA',
        'Age',
        'Gender',
        'Race',
       

#         Zip,
#         Zip9,
#         ZipSurg,
#         CrowFly,
#         ADI_State,
#         ADI_National,
#         SES,
#         Insurance,
#         Site,        
#         state
#         major_city
#         post_office_city
#         county
#         population
#         population_density
#         land_area_in_sqmi
#         water_area_in_sqmi
#         housing_units
#         occupied_housing_units
#         median_home_value
#         median_household_income
#         Pct_occupied_housing
#         families_vs_singles
#         households_with_kids
#         housing_type
#         year_housing_was_built
#         housing_occupancy
#         vacancy_reason
#         owner_occupied_home_values
#         rental_properties_by_number_of_rooms
#         monthly_rent_including_utilities_studio_apt
#         monthly_rent_including_utilities_1_b
#         monthly_rent_including_utilities_2_b
#         monthly_rent_including_utilities_3plus_b
#         employment_status
#         average_household_income_over_time
#         household_income
#         annual_individual_earnings
#         sources_of_household_income____percent_of_households_receiving_income
#         sources_of_household_income____average_income_per_household_by_income_source
#         household_investment_income____percent_of_households_receiving_investment_income
#         household_investment_income____average_income_per_household_by_income_source
#         household_retirement_income____percent_of_households_receiving_retirement_incom
#         household_retirement_income____average_income_per_household_by_income_source
#         source_of_earnings
#         means_of_transportation_to_work_for_workers_16_and_over
#         travel_time_to_work_in_minutes
#         educational_attainment_for_population_25_and_over
#         school_enrollment_age_3_to_17
        
        
        'Brand',
        'Electrode',
#         BMI,
#         ACE27,
#         FuncCap
#         ASA
#         CVD
#         CVDType
#         Resp
#         RespType
#         GIRenal
#         GIRenalType
#         DMImmune
#         DMImmuneType
#         Neuro
#         NeuroType
#         HxCancer
#         HxCancerType
#         OtherHealthIssues
        
#         Etiology_ip
#         Etiology_cl
#         HLdur_ip
#         HLdur_cl
#         HLdurSP_ip
#         HLdurSP_cl
#         HLprg_ip
#         HLprg_cl
#         HAcur_ip
#         HAcur_cl
#         HAyrs_ip
#         HAyrs_cl
#         CanUseTele_ip
#         CanUseTele_cl
#         PriorES_ip
#         PriorES_cl
#         Tinnitus_ip
#         Tinnitus_cl
#         TinniDur_ip
#         TinniDur_cl
#         NoiseExp
#         NoiseExpYrs
#         HearingAidUse
#         Prelingual
#         Tinnitus
#         Vertigo
#         Imbalance
#         FamilyHistoryHL
        
        
        'hz125_ip',
#         hz125_cl,
        'hz250_ip',
#         hz250_cl,
        'hz500_ip',
#         hz500_cl,
        'hz750_ip',
#         hz750_cl,
        'hz1000_ip',
#         hz1000_cl,
        'hz1500_ip',
#         hz1500_cl,
        'hz2000_ip',
#         hz2000_cl,
        'hz3000_ip',
#         hz3000_cl,
        'hz4000_ip',
#         hz4000_cl,
        'hz6000_ip',
#         hz6000_cl,
        'hz8000_ip',
#         hz8000_cl,
#         WRS_ip
#         WRS_cl
        
#         Spond_ip
#         Spond_cl
#         HINT_ip
#         HINT_cl
#         HINT_bi
#         HINT5SNR_ip
#         HINT5SNR_cl
#         HINT5SNR_bi
#         HINT10SNR_ip
#         HINT10SNR_cl
#         HINT10SNR_bi
        'CNC_ip',
        'CNC_cl',
        'CNC_bi',
        'AzBioQuiet_ip',
        'AzBioQuiet_cl',
        'AzBioQuiet_bi',
        'AzBio5SNR_ip',
        'AzBio5SNR_cl',
        'AzBio5SNR_bi',
        'AzBio10SNR_ip',
        'AzBio10SNR_cl',
        'AzBio10SNR_bi',
#         MOCA
#         MMSE
#         SSDCandidate
#         HybridCandidate
              
#         ElectrodePosition
#         WrapFactor
#         BasalDepth
#         BasalAngle
#         ApicalDepth
#         ApicalAngle
#         Length1stTurn
#         CochDiamRWCenter
#         CochDiamRWOrthog
#         FullInsertion
#         CT_Comments
#         IRH_Complications
        
#         InitialResidualHearing_Date
        'IRH_125hz_CI_air',
        'IRH_250hz_CI_air',
        'IRH_500hz_CI_air',
        'IRH_1000hz_CI_air',
        'IRH_2000hz_CI_air',
        'IRH_3000hz_CI_air',
        'IRH_4000hz_CI_air',
        'IRH_6000hz_CI_air',
        'IRH_8000hz_CI_air',
        
#         Month3_VisitDate
#         M3_Complications
#         M3_AvgDailyUse
        'M3_UsingEAS',
        'M3_125hz_CI_air',
        'M3_250hz_CI_air',
        'M3_500hz_CI_air',
        'M3_1000hz_CI_air',
        'M3_2000hz_CI_air',
        'M3_3000hz_CI_air',
        'M3_4000hz_CI_air',
        'M3_6000hz_CI_air',
        'M3_8000hz_CI_air',
#         M3_250hz_CI_SoundField
#         M3_500hz_CI_SoundField
#         M3_1000hz_CI_SoundField
#         M3_2000hz_CI_SoundField
#         M3_3000hz_CI_SoundField
#         M3_4000hz_CI_SoundField
#         M3_6000hz_CI_SoundField
        'M3_AzBioQuiet_ip',
        'M3_AzBio10SNR_ip',
        'M3_AzBioQuiet_bi',
        'M3_AzBio10SNR_bi',
#         M3_HINT_ip
#         M3_HINT_bi
#         M3_Spond_ip
        'M3_CNC_ip',
#         M3_Comment
        
        
        
#         Month6_VisitDate,
#         M6_Complications
#         M6_AvgDailyUse
        'M6_UsingEAS',
        'M6_125hz_CI_air',
        'M6_250hz_CI_air',
        'M6_500hz_CI_air',
        'M6_1000hz_CI_air',
        'M6_2000hz_CI_air',
        'M6_3000hz_CI_air',
        'M6_4000hz_CI_air',
        'M6_6000hz_CI_air',
        'M6_8000hz_CI_air',
#         M6_250hz_CI_SoundField
#         M6_500hz_CI_SoundField
#         M6_1000hz_CI_SoundField
#         M6_2000hz_CI_SoundField
#         M6_3000hz_CI_SoundField
#         M6_4000hz_CI_SoundField
#         M6_6000hz_CI_SoundField
        
        'M6_AzBioQuiet_ip',
        'M6_AzBio10SNR_ip',
        'M6_AzBioQuiet_bi',
        'M6_AzBio10SNR_bi',
#         M6_HINT
#         M6_HINT_bi
#         M6_Spond_ip
        'M6_CNC_ip',
#         M6_Comment
        
        
#         Month12_VisitDate
#         M12_Complications
#         M12_AvgDailyUse
        'M12_UsingEAS',
        'M12_125hz_CI_air',
        'M12_250hz_CI_air',
        'M12_500hz_CI_air',
        'M12_1000hz_CI_air',
        'M12_2000hz_CI_air',
        'M12_3000hz_CI_air',
        'M12_4000hz_CI_air',
        'M12_6000hz_CI_air',
        'M12_8000hz_CI_air',
#         M12_250hz_CI_SoundField
#         M12_500hz_CI_SoundField
#         M12_1000hz_CI_SoundField
#         M12_2000hz_CI_SoundField
#         M12_3000hz_CI_SoundField
#         M12_4000hz_CI_SoundField
#         M12_6000hz_CI_SoundField
        'M12_AzBioQuiet_ip',
        'M12_AzBio10SNR_ip',
        'M12_AzBioQuiet_bi',
        'M12_AzBio10SNR_bi',
#         M12_HINT_ip
#         M12_HINT_bi
#         M12_Spond_ip
        'M12_CNC_ip',
#         M12_MOCA
#         M12_MMSE
#         M12_Comment  
#         M6_CNC_bi
#         M6_CNC_cl
#         M6_AzBioQuiet_cl
#         M6_AzBio10SNR_cl
#         M6_AzBio5SNR_bi
#         M6_AzBio5SNR_cl
#         M6_AzBio5SNR_ip
#         M12_CNC_bi
#         M12_CNC_cl
#         M12_AzBioQuiet_cl
#         M12_AzBio10SNR_cl
#         M12_AzBio5SNR_bi
#         M12_AzBio5SNR_cl
#         M12_AzBio5SNR_ip
    
    ]
    
    df = df[cols]
    
    return df

# %%
### FULL CODE
            # 1) Load Dataset
            # 2) 
def load_dataset():

    file_name = 'CIWUSM.xlsx'
    data_dir = 'data/'
    data_path = os.path.join(data_dir, file_name)
    df = pd.read_excel(data_path)
    
    df = Fixerrors_CI_Dataset(df)
    
#     df = delete_nan_values_in_column(df, 'MRN')


#     df = correct_laterality(df, colsets=colsets)
    
#     df = add_age_at_surgery_column(df, birth_column_name = 'Date of Birth', surgery_column_name = 'export_Cochlear Implant::Date of Surgery')

    df = select_cols(df)
    
    return df

def Fixerrors_CI_Dataset(df):
    nadict = {'na':np.nan, 'NA':np.nan, ' NA':np.nan, 'nan':np.nan, 'nA':np.nan, 'NA ':np.nan, 'NO':'No', 'YES':'Yes'}
    df = df.replace(nadict)
    
    
    coldict = {
        
        'hz125_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120, '0.0':np.nan},
        'hz250_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120, '0.0':np.nan},
        'hz500_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz750_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz1000_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz2000_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz3000_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz4000_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz6000_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz8000_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz125_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz250_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz500_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz750_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120, '0':np.nan},
        'hz1000_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz1500_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120, '0':np.nan},
        'hz2000_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz3000_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120, '0.0':np.nan},
        'hz4000_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz6000_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120, '0':np.nan},
        'hz8000_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120, '0':np.nan},
        
        'IRH_125hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan},
        'IRH_250hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, 'N':np.nan},
        'IRH_500hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan},
        'IRH_1000hz_CI_air': {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan},
        'IRH_2000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan},
        'IRH_3000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan},
        'IRH_4000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan},
        'IRH_6000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan},
        'IRH_8000hz_CI_air': {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan},
        
        'M3_UsingEAS' : {30:'Yes', 80:'No', 'NA':np.nan, 'N ':'No', 120:'No', 'NA (Kanso)':np.nan, 'NA (Kanso)':np.nan, 'NA ':np.nan, '.':np.nan},
        
        'M3_125hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M3_250hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan, 'N':np.nan},
        'M3_500hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M3_1000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M3_2000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M3_3000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M3_4000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M3_6000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M3_8000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
                
        'M6_UsingEAS' : {80:'No', 'NA':np.nan, 'N ':'No', 120:'No', 'NA (Kanso)':np.nan, 'NA (Kanso)':np.nan},
        
        'M6_125hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M6_250hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan, 'N':np.nan},
        'M6_500hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M6_1000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M6_2000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M6_3000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M6_4000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M6_6000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M6_8000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        
        'M12_UsingEAS' : {80:'No', 'NA':np.nan, 'N ':'No', 120:'No', 'NA (Kanso)':np.nan, 'NA (Kanso)':np.nan},
        
        'M12_125hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M12_250hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan, 'N':np.nan, 'ns':np.nan},
        'M12_500hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M12_1000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M12_2000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M12_3000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M12_4000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M12_6000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M12_8000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},       

        
        }
    
    for col in coldict:
        for repl in coldict[col]:
            df.loc[df[col]==repl, col] = coldict[col][repl]
    
    return df

# %%
df = load_dataset()

# %%
for column_headers in df.columns: 
    print(column_headers)
# Out:
# MRN
# Exclude
# Comments_ReasonsForExclusion
# Source
# Lat
# SequentialCI
# Surgeon
# YOS
# DOS
# DOA
# Age
# Gender
# Race
# Brand
# Electrode
# hz125_ip
# hz250_ip
# hz500_ip
# hz750_ip
# hz1000_ip
# hz1500_ip
# hz2000_ip
# hz3000_ip
# hz4000_ip
# hz6000_ip
# hz8000_ip
# CNC_ip
# CNC_cl
# CNC_bi
# AzBioQuiet_ip
# AzBioQuiet_cl
# AzBioQuiet_bi
# AzBio5SNR_ip
# AzBio5SNR_cl
# AzBio5SNR_bi
# AzBio10SNR_ip
# AzBio10SNR_cl
# AzBio10SNR_bi
# IRH_125hz_CI_air
# IRH_250hz_CI_air
# IRH_500hz_CI_air
# IRH_1000hz_CI_air
# IRH_2000hz_CI_air
# IRH_3000hz_CI_air
# IRH_4000hz_CI_air
# IRH_6000hz_CI_air
# IRH_8000hz_CI_air
# M3_UsingEAS
# M3_125hz_CI_air
# M3_250hz_CI_air
# M3_500hz_CI_air
# M3_1000hz_CI_air
# M3_2000hz_CI_air
# M3_3000hz_CI_air
# M3_4000hz_CI_air
# M3_6000hz_CI_air
# M3_8000hz_CI_air
# M3_AzBioQuiet_ip
# M3_AzBio10SNR_ip
# M3_AzBioQuiet_bi
# M3_AzBio10SNR_bi
# M3_CNC_ip
# M6_UsingEAS
# M6_125hz_CI_air
# M6_250hz_CI_air
# M6_500hz_CI_air
# M6_1000hz_CI_air
# M6_2000hz_CI_air
# ...

# %% [markdown]
# # ALL CI ELECTRODES - Mean and STD

# %%
# ALL CI ELECTRDOES

# Select Columns 
selected_columns = ['CNC_ip',
                    'M3_CNC_ip',
                    'M6_CNC_ip',
                    'M12_CNC_ip',
                    
                    'AzBioQuiet_bi',
                    'M3_AzBioQuiet_bi',
                    'M6_AzBioQuiet_bi',
                    'M12_AzBioQuiet_bi',
                    
                    'AzBio10SNR_bi',
                    'M3_AzBio10SNR_bi',
                    'M6_AzBio10SNR_bi',
                    'M12_AzBio10SNR_bi'                  
                    
                   ]

# Calculate mean for selected columns
mean_values = df[selected_columns].mean()

# Calculate standard deviation for selected columns
std_values = df[selected_columns].std()

# Calculate sample size for selected columns
sample_size = df[selected_columns].count()

# Combine mean, standard deviation, and sample size into a DataFrame
result_df = pd.DataFrame({'Mean': mean_values, 'Standard Deviation': std_values, 'Sample Size': sample_size})

# Display the result
print(result_df)

# %% [markdown]
# # All Cochlear Brand

# %%
## Select Cochlear Only - ALL SPEECH PERCEPTION DATA

# Define the value you want to filter on and the column name
value_to_filter = 'Cochlear'
column_to_filter = 'Brand'

# Filter the DataFrame based on the specified value in the specified column
filtered_df = df[df[column_to_filter] == value_to_filter]


# Select Columns 
selected_columns = ['CNC_ip',
                    'M3_CNC_ip',
                    'M6_CNC_ip',
                    'M12_CNC_ip',
                    
                    'AzBioQuiet_bi',
                    'M3_AzBioQuiet_bi',
                    'M6_AzBioQuiet_bi',
                    'M12_AzBioQuiet_bi',
                    
                    'AzBio10SNR_bi',
                    'M3_AzBio10SNR_bi',
                    'M6_AzBio10SNR_bi',
                    'M12_AzBio10SNR_bi',                  
                    
                   ]

mean_values = filtered_df[selected_columns].mean()
std_values = filtered_df[selected_columns].std()
sample_size = filtered_df[selected_columns].count()


# Combine mean, standard deviation, and sample size into a DataFrame
result_df = pd.DataFrame({'Mean': mean_values, 'Standard Deviation': std_values, 'Sample Size': sample_size})

# Display the result
print(result_df)

# %% [markdown]
# # Cochlear PM Electrodes

# %%
## Select Cochlear CI 632 ONLY

value_to_filter1 = 'Cochlear'
column_to_filter1 = 'Brand'
value_to_filter2 = 'PM'
column_to_filter2 = 'Electrode'

filtered_df = df[(df[column_to_filter1] == value_to_filter1) & (df[column_to_filter2] == value_to_filter2)]


# Select Columns 
selected_columns = ['CNC_ip',
                    'M3_CNC_ip',
                    'M6_CNC_ip',
                    'M12_CNC_ip',
                    
                    'AzBioQuiet_bi',
                    'M3_AzBioQuiet_bi',
                    'M6_AzBioQuiet_bi',
                    'M12_AzBioQuiet_bi',
                    
                    'AzBio10SNR_bi',
                    'M3_AzBio10SNR_bi',
                    'M6_AzBio10SNR_bi',
                    'M12_AzBio10SNR_bi'                  
                    
                   ]

mean_values = filtered_df[selected_columns].mean()
std_values = filtered_df[selected_columns].std()
sample_size = filtered_df[selected_columns].count()


# Combine mean, standard deviation, and sample size into a DataFrame
result_df = pd.DataFrame({'Mean': mean_values, 'Standard Deviation': std_values, 'Sample Size': sample_size})

# Display the result
print(result_df)

# %% [markdown]
# # Cochlear PM Hearing Preservation information

# %%
## Select Cochlear CI 632 ONLY
## Hearing Preservation Data

value_to_filter1 = 'Cochlear'
column_to_filter1 = 'Brand'
value_to_filter2 = 'PM'
column_to_filter2 = 'Electrode'

filtered_df = df[(df[column_to_filter1] == value_to_filter1) & (df[column_to_filter2] == value_to_filter2)]


# Select Columns 
selected_columns = ['CNC_ip',
                    'M3_CNC_ip',
                    'M6_CNC_ip',
                    'M12_CNC_ip',
                    
                    'AzBioQuiet_bi',
                    'M3_AzBioQuiet_bi',
                    'M6_AzBioQuiet_bi',
                    'M12_AzBioQuiet_bi',
                    
                    'AzBio10SNR_bi',
                    'M3_AzBio10SNR_bi',
                    'M6_AzBio10SNR_bi',
                    'M12_AzBio10SNR_bi',
                    
                    'hz125_ip',
                    'hz250_ip',
                    'hz500_ip',
                    
                    'IRH_125hz_CI_air',
                    'IRH_250hz_CI_air',
                    'IRH_500hz_CI_air',
                    
                    'M3_UsingEAS',
                    'M3_125hz_CI_air',
                    'M3_250hz_CI_air',
                    'M3_500hz_CI_air',
                    
                    'M6_UsingEAS',
                    'M6_125hz_CI_air',
                    'M6_250hz_CI_air',
                    'M6_500hz_CI_air',
                    
                    'M12_UsingEAS',
                    'M12_125hz_CI_air',
                    'M12_250hz_CI_air',
                    'M12_500hz_CI_air'
                                                     
                   ]

mean_values = filtered_df[selected_columns].mean(skipna=True)
std_values = filtered_df[selected_columns].std(skipna=True)
sample_size = filtered_df[selected_columns].count()


# Combine mean, standard deviation, and sample size into a DataFrame
result_df = pd.DataFrame({'Mean': mean_values, 'Standard Deviation': std_values, 'Sample Size': sample_size})

# Display the result

result_df.to_excel('CI_WUSM Registry1_632.xlsx', index=True)

print(result_df)
# Out:
#                          Mean  Standard Deviation  Sample Size
# AzBio10SNR_bi       32.078544           30.427907          522
# AzBioQuiet_bi       48.455939           32.200413          522
# CNC_ip              13.914286           14.770631          560
# IRH_125hz_CI_air    88.600000           28.126594          415
# IRH_250hz_CI_air    93.959459           23.972768          444
# IRH_500hz_CI_air    99.258140           21.160082          430
# M12_125hz_CI_air    94.943503           28.279192          177
# M12_250hz_CI_air    98.612565           24.789358          191
# M12_500hz_CI_air   103.769634           21.328985          191
# M12_AzBio10SNR_bi   56.029484           25.007371          407
# M12_AzBioQuiet_bi   73.120823           22.205305          389
# M12_CNC_ip          53.270270           20.519844          555
# M12_UsingEAS              NaN                 NaN          284
# M3_125hz_CI_air     86.818182           28.225529          242
# ...

# %%
df['Electrode'].tolist()

# %% [markdown]
# # Graveyard

# %%
## Graveyard for Future Use - dictionary replacement
def Fixerrors_CI_Dataset(df):
    nadict = {'na':np.nan, 'NA':np.nan, ' NA':np.nan, 'nan':np.nan, 'nA':np.nan, 'NA ':np.nan, 'NO':'No', 'YES':'Yes'}
    df = df.replace(nadict)
    
    
    coldict = {
        
        'hz125_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120, '0.0':np.nan},
        'hz250_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120, '0.0':np.nan},
        'hz500_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz750_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz1000_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz2000_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz3000_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz4000_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz6000_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz8000_ip' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz125_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz250_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz500_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz750_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120, '0':np.nan},
        'hz1000_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz1500_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120, '0':np.nan},
        'hz2000_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz3000_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120, '0.0':np.nan},
        'hz4000_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120},
        'hz6000_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120, '0':np.nan},
        'hz8000_cl' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'PTA 93':np.nan, 199:np.nan, 'PTA 54':np. nan, -5:np.nan, 121:120, 122:120, '0':np.nan},
        
        'IRH_125hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan},
        'IRH_250hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, 'N':np.nan},
        'IRH_500hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan},
        'IRH_1000hz_CI_air': {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan},
        'IRH_2000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan},
        'IRH_3000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan},
        'IRH_4000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan},
        'IRH_6000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan},
        'IRH_8000hz_CI_air': {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan},
        
        'M3_UsingEAS' : {30:'Yes', 80:'No', 'NA':np.nan, 'N ':'No', 120:'No', 'NA (Kanso)':np.nan, 'NA (Kanso)':np.nan, 'NA ':np.nan, '.':np.nan},
        
        'M3_125hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M3_250hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan, 'N':np.nan},
        'M3_500hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M3_1000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M3_2000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M3_3000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M3_4000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M3_6000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M3_8000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
                
        'M6_UsingEAS' : {80:'No', 'NA':np.nan, 'N ':'No', 120:'No', 'NA (Kanso)':np.nan, 'NA (Kanso)':np.nan},
        
        'M6_125hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M6_250hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan, 'N':np.nan},
        'M6_500hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M6_1000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M6_2000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M6_3000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M6_4000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M6_6000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M6_8000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        
        'M12_UsingEAS' : {80:'No', 'NA':np.nan, 'N ':'No', 120:'No', 'NA (Kanso)':np.nan, 'NA (Kanso)':np.nan},
        
        'M12_125hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M12_250hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan, 'N':np.nan, 'ns':np.nan},
        'M12_500hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M12_1000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M12_2000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M12_3000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M12_4000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M12_6000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},
        'M12_8000hz_CI_air' : {'Not in chart':np.nan, 'NR':120, 'nr':120, 'DNT':np.nan, 'CI':np.nan, 'NNA':np.nan, 'VT':np.nan, 1250:120, 'nan':np.nan, 125:120, 'NA':np.nan, '74':75, '0':np.nan, '1':np.nan},       

        
        }
    
    for col in coldict:
        for repl in coldict[col]:
            df.loc[df[col]==repl, col] = coldict[col][repl]
    
    return df

# %%
df['M12_250hz_CI_air'].unique()
# Out:
# array([nan, 120, 95, 75, 105, 85, 55, 100, 90, 70, 65, 60, 50, 35, 45, 80,
#        30, 5, 20, 25, 40], dtype=object)
